# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mha_time = {2048: 0.0005837744101881981, 4096: 0.0005178376100957394, 8192: 0.001621034392155707, 16384: 0.004670886206440628, 32768: 0.017562088603153826, 65536: 0.06859703480731696, 131072: 0.2712307058041915}
mha_backward_time = {2048: 0.0007558168144896626, 4096: 0.0012046047020703554, 8192: 0.003908695420250297, 16384: 0.011010079714469611, 32768: 0.04176229359582066, 65536: 0.16497112980578094, 131072: 0.6590767577057705}

hyena_time = {2048: 0.0015634472016245126, 4096: 0.0011492535937577485, 8192: 0.0015433256048709154, 16384: 0.002953139622695744, 32768: 0.005692799598909915, 65536: 0.011841464205645025, 131072: 0.028534771711565553}
hyena_backward_time = {2048: 0.002042770921252668, 4096: 0.00238292848225683, 8192: 0.0034361713100224734, 16384: 0.006351319118402898, 32768: 0.012277411203831435, 65536: 0.028758645593188702, 131072: 0.07687162519432604}

# %%
plt.plot(list(mha_time.keys()), list(mha_time.values()), label="MHA")
plt.plot(list(hyena_time.keys()), list(hyena_time.values()), label="HyENA")
plt.xlabel("Sequence Length")
plt.ylabel("Runtime (s)")
plt.legend()
plt.savefig("forward runtime.png")
plt.show()

# %%
plt.plot(list(mha_backward_time.keys()), list(mha_backward_time.values()), label="MHA")
plt.plot(list(hyena_backward_time.keys()), list(hyena_backward_time.values()), label="HyENA")
plt.xlabel("Sequence Length")
plt.ylabel("Runtime (s)")
plt.legend()
plt.savefig("forward runtime.png")
plt.show()
